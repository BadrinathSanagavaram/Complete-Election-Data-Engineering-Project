# %% [markdown]
# ## Data Extraction and Web Scraping

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests

# %%
url = "https://en.wikipedia.org/wiki/Results_of_the_2019_Indian_general_election"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
a= soup.find_all('table',class_='wikitable sortable')

# %%
len(a)
# Out:
# 39

# %%
with open("output.txt", "w") as file_object:
    for table in a:
        file_object.write(str(table))
        file_object.write("\n\n")

# %%
main_table = a[38]
main_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th rowspan="2">State
# </th>
# <th colspan="3">Parliamentary Constituency
# </th>
# <th colspan="4">Winner
# </th>
# <th colspan="4">Runner Up
# </th>
# <th data-sort-type="number" rowspan="2">Margin
# </th>
# <th>Margin %
# </th></tr>
# <tr>
# <th>No.
# </th>
# <th>Name
# </th>
# <th>Type
# </th>
# <th>Candidate
# </th>
# <th colspan="2">Party
# </th>
# <th data-sort-type="number">Votes (Vote%)
# </th>
# <th>Candidate
# </th>
# <th colspan="2">Party
# </th>
# <th data-sort-type="number">Votes (Vote%)
# </th>
# <th>
# </th></tr>
# <tr>
# <th><a href="/wiki/Andaman_and_Nicobar_Islands" title="Andaman and Nicobar Islands">Andaman and Nicobar Islands</a>
# </th>
# <td>1
# </td>
# <td><a class="mw-redirect" href="/wiki/Andaman_and_Nicobar_Islands_(Lok_Sabha_constituency)" title="Andaman and Nicobar Islands (Lok Sabha constituency)">Andaman and Nicobar Islands</a>
# </td>
# <td>GEN
# </td>
# ...

# %%
all_headers = []
for i in main_table.find_all('th'):
    all_headers.append(i.text.strip())

# %%
main_headers = all_headers[:15]
state_names = all_headers[16:]

# %%
main_headers
# Out:
# ['State',
#  'Parliamentary Constituency',
#  'Winner',
#  'Runner Up',
#  'Margin',
#  'Margin\xa0%',
#  'No.',
#  'Name',
#  'Type',
#  'Candidate',
#  'Party',
#  'Votes (Vote%)',
#  'Candidate',
#  'Party',
#  'Votes (Vote%)']

# %%
del main_headers[1:4]
main_headers
del main_headers[1:3]
main_headers.extend(additional_headers)

# %%
additional_headers = ["Margin", "Margin %"]

# %%
main_headers
# Out:
# ['State',
#  'No.',
#  'Name',
#  'Type',
#  'Candidate',
#  'Party',
#  'Votes (Vote%)',
#  'Candidate',
#  'Party',
#  'Votes (Vote%)',
#  'Margin',
#  'Margin %']

# %%
df = pd.DataFrame(columns=main_headers)
df.drop(columns='State', inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [No., Name, Type, Candidate, Party, Votes (Vote%), Candidate, Party, Votes (Vote%), Margin, Margin %]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [No., Name, Type, Candidate, Party, Votes (Vote%), Candidate, Party, Votes (Vote%), Margin, Margin %]
# Index: []

# %%
individual_rows = []
for i in main_table.find_all('tr'):
    rows = [j.text.strip() for j in i.find_all('td')]
    individual_rows.append(rows)
    print(rows)
# Out:
# []
# []
# ['1', 'Andaman and Nicobar Islands', 'GEN', 'Kuldeep Rai Sharma', '', 'INC', '95,308 (45.95%)', 'Vishal Jolly', '', 'Bharatiya Janata Party', '93,901 (45.28%)', '1,407', '0.67%']
# ['1', 'Araku', '(ST)', 'Goddeti Madhavi', '', 'YSRCP', '5,62,190 (52.14%)', 'Kishore Chandra Deo', '', 'TDP', '3,38,101 (31.36%)', '2,24,089', '20.78%']
# ['2', 'Srikakulam', 'GEN', 'Ram Mohan Naidu Kinjarapu', '', 'TDP', '5,34,544 (45.91%)', 'Duvvada Srinivas', '', 'YSRCP', '5,27,891 (45.34%)', '6,653', '0.57%']
# ['3', 'Vizianagaram', 'GEN', 'Bellana Chandra Sekhar', '', 'YSRCP', '5,78,418 (47.32%)', 'Ashok Gajapathi Raju', '', 'TDP', '5,30,382 (43.39%)', '48,036', '3.93%']
# ['4', 'Visakhapatnam', 'GEN', 'M. V. V. Satyanarayana', '', 'YSRCP', '4,36,906 (35.24%)', 'Bharat Mathukumilli', '', 'TDP', '4,32,492 (34.88%)', '4,414', '0.36%']
# ['5', 'Anakapalli', 'GEN', 'Beesetti Venkata Satyavathi', '', 'YSRCP', '5,86,226 (47.26%)', 'Aadari Anand', '', 'TDP', '4,97,034 (40.07%)', '89,192', '7.19%']
# ...

# %%
individual_rows = individual_rows[2:]

# %%
for i in individual_rows:
    del i[8]
    del i[4]
    print(i)
    length = len(df)
    df.loc[length] = i
# Out:
# ['1', 'Andaman and Nicobar Islands', 'GEN', 'Kuldeep Rai Sharma', 'INC', '95,308 (45.95%)', 'Vishal Jolly', 'Bharatiya Janata Party', '93,901 (45.28%)', '1,407', '0.67%']
# ['1', 'Araku', '(ST)', 'Goddeti Madhavi', 'YSRCP', '5,62,190 (52.14%)', 'Kishore Chandra Deo', 'TDP', '3,38,101 (31.36%)', '2,24,089', '20.78%']
# ['2', 'Srikakulam', 'GEN', 'Ram Mohan Naidu Kinjarapu', 'TDP', '5,34,544 (45.91%)', 'Duvvada Srinivas', 'YSRCP', '5,27,891 (45.34%)', '6,653', '0.57%']
# ['3', 'Vizianagaram', 'GEN', 'Bellana Chandra Sekhar', 'YSRCP', '5,78,418 (47.32%)', 'Ashok Gajapathi Raju', 'TDP', '5,30,382 (43.39%)', '48,036', '3.93%']
# ['4', 'Visakhapatnam', 'GEN', 'M. V. V. Satyanarayana', 'YSRCP', '4,36,906 (35.24%)', 'Bharat Mathukumilli', 'TDP', '4,32,492 (34.88%)', '4,414', '0.36%']
# ['5', 'Anakapalli', 'GEN', 'Beesetti Venkata Satyavathi', 'YSRCP', '5,86,226 (47.26%)', 'Aadari Anand', 'TDP', '4,97,034 (40.07%)', '89,192', '7.19%']
# ...

# %%
df_2024 = pd.read_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/raw-data/2024-election-dataset-raw.csv')
df_2019 = pd.read_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/raw-data/2019-election-dataset-raw.csv')
print(df_2024.columns)
print(df_2019.columns)
# Out:
# Index(['Unnamed: 0', 'State', 'No.', 'Name', 'Type', 'Candidate', 'Party', '%',
#        'Votes', 'Candidate.1', 'Party.1', '%.1', 'Votes.1', '%.2', 'Votes.2'],
#       dtype='object')
# Index(['Unnamed: 0', 'No.', 'Name', 'Type', 'Candidate', 'Party',
#        'Votes (Vote%)', 'Candidate.1', 'Party.1', 'Votes (Vote%).1', 'Margin',
#        'Margin %'],
#       dtype='object')

# %%
for df in (df_2024, df_2019):
    # drop auto‑index column if still present
    df.drop(columns="Unnamed: 0", errors="ignore", inplace=True)
    # trim stray white‑space in the join keys
    df["Name"] = df["Name"].str.strip()
    # make sure key dtypes match (e.g. int vs object)
    df["No."] = pd.to_numeric(df["No."], errors="coerce")

# --- 2.  Build a slim lookup from df_2024 -------------------------------
state_lookup = (
    df_2024[["No.", "Name", "State"]]   # only what we need
          .drop_duplicates()            # guard against duplicates
)

# --- 3.  Merge the two tables -------------------------------------------
df_2019_with_state = (
    df_2019
      .merge(state_lookup,              # right‑side table
             on=["No.", "Name"],        # join keys
             how="left")       )

# %%
df_2019_with_state[['Name','State']][df_2019_with_state['State'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, State]
# Index: []

# %%
const_to_state = {
    # Andaman & Nicobar
    "Andaman and Nicobar Islands" : "Andaman and Nicobar Islands",

    # Assam
    "Karimganj"        : "Assam",
    "Silchar"          : "Assam",
    "Autonomous District" : "Assam",
    "Dhubri"           : "Assam",
    "Kokrajhar"        : "Assam",
    "Barpeta"          : "Assam",
    "Gauhati"          : "Assam",
    "Mangaldoi"        : "Assam",
    "Tezpur"           : "Assam",
    "Nowgong"          : "Assam",
    "Kaliabor"         : "Assam",
    "Jorhat"           : "Assam",
    "Lakhimpur"        : "Assam",

    # Chhattisgarh
    "Janjgir-Champa"   : "Chhattisgarh",

    # Dadra & Nagar Haveli
    "Dadra And Nagar Haveli" : "Dadra and Nagar Haveli and Daman and Diu",

    # Gujarat
    "Surat"            : "Gujarat",

    # Haryana
    "Bhiwani–Mahendragarh" : "Haryana",

    # Jammu & Kashmir / Ladakh
    "Anantnag"         : "Jammu and Kashmir",
    "Udhampur"         : "Jammu and Kashmir",
    "Jammu"            : "Jammu and Kashmir",
    "Ladakh"           : "Ladakh",

    # Jharkhand
    "Kodarma"          : "Jharkhand",
    "Lohardaga"        : "Jharkhand",
    "Palamau"          : "Jharkhand",

    # Kerala
    "Mavelikkara"      : "Kerala",

    # Madhya Pradesh
    "Bhind"            : "Madhya Pradesh",
    "Tikamgarh"        : "Madhya Pradesh",
    "Khajuraho"        : "Madhya Pradesh",
    "Sidhi"            : "Madhya Pradesh",
    "Shahdol"          : "Madhya Pradesh",
    "Bhopal"           : "Madhya Pradesh",
    "Rajgarh"          : "Madhya Pradesh",

    # Maharashtra
    "Bhandara-Gondiya"     : "Maharashtra",
    "Gadchiroli-Chimur"    : "Maharashtra",
    "Yavatmal-Washim"      : "Maharashtra",
    "Ratnagiri-Sindhudurg" : "Maharashtra",

    # Punjab
    "Ferozpur"         : "Punjab",

    # Tamil Nadu
    "Viluppuram"       : "Tamil Nadu",
    "Mayiladuthurai"   : "Tamil Nadu",
    "Thoothukkudi"     : "Tamil Nadu",
    "Kanyakumari"      : "Tamil Nadu",

    # Telangana
    "Peddapalli"       : "Telangana",

    # Uttar Pradesh
    "Gautam Buddh Nagar" : "Uttar Pradesh",
    "Kanpur Urban"       : "Uttar Pradesh",

    # Uttarakhand
    "Nainital–Udhamsingh Nagar" : "Uttarakhand",

    # West Bengal
    "Maldaha Uttar"     : "West Bengal",
    "Maldaha Dakshin"   : "West Bengal",
    "Bangaon"           : "West Bengal",
    "Barrackpore"       : "West Bengal",
    "Dum Dum"           : "West Bengal",
    "Barasat"           : "West Bengal",
    "Basirhat"          : "West Bengal",
    "Jaynagar"          : "West Bengal",
    "Mathurapur"        : "West Bengal",
    "Diamond Harbour"   : "West Bengal",
    "Bardhaman-Durgapur": "West Bengal",
    "Bolpur"            : "West Bengal",
}
df_2019_with_state['State']=df_2019_with_state['State'].fillna(df_2019_with_state['Name'].map(const_to_state))

# %%
df_2019_with_state.to_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/2019-election-dataset-raw.csv')

# %% [markdown]
# ## Data Transformation

# %%
df = pd.read_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/raw-data/2019-election-dataset-raw.csv')
df.head(5)
# Out:
#    Unnamed: 0  No.                         Name  Type  \
# 0           0    1  Andaman and Nicobar Islands   GEN
# 1           1    1                        Araku  (ST)
# 2           2    2                   Srikakulam   GEN
# 3           3    3                 Vizianagaram   GEN
# 4           4    4                Visakhapatnam   GEN
#
#                    Candidate  Party      Votes (Vote%)           Candidate.1  \
# 0         Kuldeep Rai Sharma    INC    95,308 (45.95%)          Vishal Jolly
# 1            Goddeti Madhavi  YSRCP  5,62,190 (52.14%)   Kishore Chandra Deo
# 2  Ram Mohan Naidu Kinjarapu    TDP  5,34,544 (45.91%)      Duvvada Srinivas
# 3     Bellana Chandra Sekhar  YSRCP  5,78,418 (47.32%)  Ashok Gajapathi Raju
# 4     M. V. V. Satyanarayana  YSRCP  4,36,906 (35.24%)   Bharat Mathukumilli
#
#                   Party.1    Votes (Vote%).1    Margin Margin %  \
# 0  Bharatiya Janata Party    93,901 (45.28%)     1,407    0.67%
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head(5)
# Out:
#    No.                         Name  Type                  Candidate  Party  \
# 0    1  Andaman and Nicobar Islands   GEN         Kuldeep Rai Sharma    INC
# 1    1                        Araku  (ST)            Goddeti Madhavi  YSRCP
# 2    2                   Srikakulam   GEN  Ram Mohan Naidu Kinjarapu    TDP
# 3    3                 Vizianagaram   GEN     Bellana Chandra Sekhar  YSRCP
# 4    4                Visakhapatnam   GEN     M. V. V. Satyanarayana  YSRCP
#
#        Votes (Vote%)           Candidate.1                 Party.1  \
# 0    95,308 (45.95%)          Vishal Jolly  Bharatiya Janata Party
# 1  5,62,190 (52.14%)   Kishore Chandra Deo                     TDP
# 2  5,34,544 (45.91%)      Duvvada Srinivas                   YSRCP
# 3  5,78,418 (47.32%)  Ashok Gajapathi Raju                     TDP
# 4  4,36,906 (35.24%)   Bharat Mathukumilli                     TDP
#
#      Votes (Vote%).1    Margin Margin %                        State
# ...

# %%
state_to_consti_map = {
    'Andaman and Nicobar Islands': ['Andaman and Nicobar Islands'],
    'Andhra Pradesh': [
        'Araku','Srikakulam','Vizianagaram','Visakhapatnam','Anakapalli',
        'Kakinada','Amalapuram','Rajahmundry','Narasapuram','Eluru',
        'Machilipatnam','Vijayawada','Guntur','Narasaraopet','Bapatla',
        'Ongole','Nandyal','Kurnool','Anantapur','Hindupur',
        'Kadapa','Nellore','Tirupati','Rajampet','Chittoor'
    ],
    'Arunachal Pradesh': ['Arunachal West','Arunachal East'],
    'Assam': [
        'Kokrajhar','Dhubri','Barpeta','Darrang–Udalguri','Guwahati',
        'Diphu','Karimganj','Silchar','Nagaon','Kaziranga',
        'Sonitpur','Lakhimpur','Dibrugarh','Jorhat'
    ],
    'Bihar': [
        'Valmiki Nagar','Paschim Champaran','Purvi Champaran','Sheohar',
        'Sitamarhi','Madhubani','Jhanjharpur','Supaul','Araria',
        'Kishanganj','Katihar','Purnia','Madhepura','Darbhanga',
        'Muzaffarpur','Vaishali','Gopalganj','Siwan','Maharajganj',
        'Saran','Hajipur','Ujiarpur','Samastipur','Begusarai',
        'Khagaria','Bhagalpur','Banka','Munger','Nalanda',
        'Patna Sahib','Pataliputra','Arrah','Buxar','Sasaram',
        'Karakat','Jahanabad','Aurangabad','Gaya','Nawada','Jamui'
    ],
    'Chandigarh': ['Chandigarh'],
    'Chhattisgarh': [
        'Sarguja','Raigarh','Janjgir‑Champa','Korba','Bilaspur',
        'Rajnandgaon','Durg','Raipur','Mahasamund','Bastar','Kanker'
    ],
    'Dadra and Nagar Haveli and Daman and Diu': [
        'Daman and Diu','Dadra and Nagar Haveli'
    ],
    'Delhi': [
        'Chandni Chowk','North East Delhi','East Delhi','New Delhi',
        'North West Delhi','West Delhi','South Delhi'
    ],
    'Goa': ['North Goa','South Goa'],
    'Gujarat': [
        'Kachchh','Banaskantha','Patan','Mahesana','Sabarkantha',
        'Gandhinagar','Ahmedabad East','Ahmedabad West','Surendranagar',
        'Rajkot','Porbandar','Jamnagar','Junagadh','Amreli','Bhavnagar',
        'Anand','Kheda','Panchmahal','Dahod','Vadodara',
        'Chhota Udaipur','Bharuch','Bardoli','Surat','Navsari','Valsad'
    ],
    'Haryana': [
        'Ambala','Kurukshetra','Sirsa','Hisar','Karnal','Sonipat',
        'Rohtak','Bhiwani‑Mahendragarh','Gurgaon','Faridabad'
    ],
    'Himachal Pradesh': [
        'Hamirpur','Mandi','Shimla','Kangra'
    ],
    'Jammu and Kashmir': [
        'Srinagar','Baramulla','Anantnag–Rajouri','Udhampur','Jammu'
    ],
    'Jharkhand': [
        'Chatra','Giridih','Ranchi','Jamshedpur','Dhanbad',
        'Singhbhum','Hazaribagh','Palamu','Godda','Rajmahal',
        'Khunti','Dumka','Garhwa','Sahibganj'
    ],
    'Karnataka': [
        'Chikkodi','Belgaum','Bagalkot','Bijapur','Gulbarga','Raichur',
        'Bidar','Koppal','Bellary','Haveri','Dharwad','Uttara Kannada',
        'Davanagere','Shimoga','Udupi Chikmagalur','Hassan',
        'Dakshina Kannada','Chitradurga','Tumkur','Mandya','Mysore',
        'Chamarajanagar','Bangalore Rural','Bangalore North',
        'Bangalore Central','Bangalore South','Chikballapur','Kolar'
    ],
    'Kerala': [
        'Kasaragod','Kannur','Vatakara','Wayanad','Kozhikode','Malappuram',
        'Ponnani','Palakkad','Alathur','Thrissur','Chalakudy','Ernakulam',
        'Idukki','Kottayam','Alappuzha','Mavelikara','Pathanamthitta',
        'Kollam','Attingal','Thiruvananthapuram'
    ],
    'Ladakh': ['Ladakh'],
    'Lakshadweep': ['Lakshadweep'],
    'Madhya Pradesh': [
        'Balaghat','Betul','Chhindwara','Damoh','Dewas','Dhar',
        'Guna','Gwalior','Harda','Hoshangabad','Indore','Jabalpur',
        'Khandwa','Khargone','Mandla','Mandsaur','Morena','Narmadapuram',
        'Neemuch','Panna','Rewa','Sagar','Satna','Seoni','Sehore',
        'Shivpuri','Ujjain','Vidisha','Ratlam'
    ],
    'Maharashtra': [
        'Nandurbar','Dhule','Jalgaon','Raver','Buldhana','Akola','Amravati',
        'Wardha','Ramtek','Nagpur','Bhandara‑Gondiya','Gadchiroli‑Chimur',
        'Chandrapur','Yavatmal‑Washim','Hingoli','Nanded','Parbhani',
        'Jalna','Aurangabad','Dindori','Nashik','Palghar','Bhiwandi',
        'Kalyan','Thane','Mumbai North','Mumbai North West','Mumbai North East',
        'Mumbai North Central','Mumbai South Central','Mumbai South',
        'Raigad','Maval','Pune','Baramati','Shirur','Ahmednagar',
        'Shirdi','Beed','Osmanabad','Latur','Solapur','Madha','Sangli',
        'Satara','Ratnagiri‑Sindhudurg','Kolhapur','Hatkanangle'
    ],
    'Manipur': ['Inner Manipur','Outer Manipur'],
    'Meghalaya': ['Shillong','Tura'],
    'Mizoram': ['Mizoram'],
    'Nagaland': ['Nagaland'],
    'Odisha': [
        'Bargarh','Sundargarh','Sambalpur','Keonjhar','Mayurbhanj',
        'Balasore','Bhadrak','Jajpur','Dhenkanal','Bolangir','Kalahandi',
        'Nabarangpur','Kandhamal','Cuttack','Kendrapara','Jagatsinghpur',
        'Puri','Bhubaneswar','Aska','Berhampur','Koraput'
    ],
    'Puducherry': ['Puducherry'],
    'Punjab': [
        'Gurdaspur','Amritsar','Khadoor Sahib','Jalandhar','Hoshiarpur',
        'Anandpur Sahib','Ludhiana','Fatehgarh Sahib','Faridkot','Firozpur',
        'Bathinda','Sangrur','Patiala'
    ],
    'Rajasthan': [
        'Ganganagar','Bikaner','Churu','Jhunjhunu','Sikar','Jaipur Rural',
        'Jaipur','Alwar','Bharatpur','Karauli–Dholpur','Dausa',
        'Tonk–Sawai Madhopur','Ajmer','Nagaur','Pali','Jodhpur','Barmer',
        'Jalore','Udaipur','Banswara','Chittorgarh','Rajsamand','Bhilwara',
        'Kota','Jhalawar–Baran'
    ],
    'Sikkim': ['Sikkim'],
    'Tamil Nadu': [
        'Thiruvallur','Chennai North','Chennai South','Chennai Central',
        'Sriperumbudur','Kancheepuram','Arakkonam','Vellore','Krishnagiri',
        'Dharmapuri','Tiruvannamalai','Arani','Villupuram','Kallakurichi',
        'Salem','Namakkal','Erode','Tiruppur','Nilgiris','Coimbatore',
        'Pollachi','Dindigul','Karur','Tiruchirappalli','Perambalur',
        'Cuddalore','Chidambaram','Mayiladuturai','Nagapattinam','Thanjavur',
        'Sivaganga','Madurai','Theni','Virudhunagar','Ramanathapuram',
        'Thoothukkudi','Tenkasi','Tirunelveli','Kanniyakumari'
    ],
    'Telangana': [
        'Adilabad','Peddapalle','Karimnagar','Nizamabad','Zahirabad',
        'Medak','Malkajgiri','Secunderabad','Hyderabad','Chevella',
        'Mahbubnagar','Nagarkurnool','Nalgonda','Bhongir','Warangal',
        'Mahabubabad','Khammam'
    ],
    'Tripura': ['Tripura East','Tripura West'],
    'Uttar Pradesh': [
        'Saharanpur','Kairana','Muzaffarnagar','Bijnor','Nagina','Moradabad',
        'Rampur','Sambhal','Amroha','Meerut','Baghpat','Ghaziabad',
        'Gautam Buddha Nagar','Bulandshahr','Aligarh','Hathras','Mathura',
        'Agra','Fatehpur Sikri','Firozabad','Mainpuri','Etah','Badaun',
        'Aonla','Bareilly','Pilibhit','Shahjahanpur','Kheri','Dhaurahra',
        'Sitapur','Hardoi','Misrikh','Unnao','Mohanlalganj','Lucknow',
        'Rae Bareli','Amethi','Sultanpur','Pratapgarh','Farrukhabad',
        'Etawah','Kannauj','Kanpur','Akbarpur','Jalaun','Jhansi','Hamirpur',
        'Banda','Fatehpur','Kaushambi','Phulpur','Allahabad','Barabanki',
        'Faizabad','Ambedkar Nagar','Bahraich','Kaiserganj','Shrawasti',
        'Gonda','Domariyaganj','Basti','Sant Kabir Nagar','Maharajganj',
        'Gorakhpur','Kushi Nagar','Deoria','Bansgaon','Lalganj','Azamgarh',
        'Ghosi','Salempur','Ballia','Jaunpur','Machhlishahr','Ghazipur',
        'Chandauli','Varanasi','Bhadohi','Mirzapur','Robertsganj'
    ],
    'Uttarakhand': ['Tehri Garhwal','Garhwal','Almora','Nainital–Udhamsingh Nagar','Haridwar'],
    'West Bengal': [
        'Cooch Behar','Alipurduars','Jalpaiguri','Darjeeling','Raiganj',
        'Balurghat','Malda North','Malda South','Murshidabad','Jangipur',
        'Baharampur','Krishnanagar','Ranaghat','Bishnupur','Tamluk',
        'Kanthi','Ghatal','Jhargram','Medinipur','Purulia','Bankura',
        'Bardhaman Purba','Bardhaman Durgapur','Hooghly','Serampore',
        'Arambagh','T.U.Dhaka','Howrah','Uluberia','Sreerampur',
        'Baharampur','Birbhum','Asansol','Durgapur','Jadavpur','Kolkata Dakshin',
        'Kolkata Uttar','Balurghat'
    ]
}

# %%
consti_to_state_map = {}
for state, constituencies in state_to_consti_map.items():
    for consti in constituencies:
        consti_to_state_map[consti] = state
df['State'] = df['Name'].map(consti_to_state_map)
consti_to_state_map
df.head(5)
# Out:
#    No.                         Name  Type                  Candidate  Party  \
# 0    1  Andaman and Nicobar Islands   GEN         Kuldeep Rai Sharma    INC
# 1    1                        Araku  (ST)            Goddeti Madhavi  YSRCP
# 2    2                   Srikakulam   GEN  Ram Mohan Naidu Kinjarapu    TDP
# 3    3                 Vizianagaram   GEN     Bellana Chandra Sekhar  YSRCP
# 4    4                Visakhapatnam   GEN     M. V. V. Satyanarayana  YSRCP
#
#        Votes (Vote%)           Candidate.1                 Party.1  \
# 0    95,308 (45.95%)          Vishal Jolly  Bharatiya Janata Party
# 1  5,62,190 (52.14%)   Kishore Chandra Deo                     TDP
# 2  5,34,544 (45.91%)      Duvvada Srinivas                   YSRCP
# 3  5,78,418 (47.32%)  Ashok Gajapathi Raju                     TDP
# 4  4,36,906 (35.24%)   Bharat Mathukumilli                     TDP
#
#      Votes (Vote%).1    Margin Margin %                        State
# ...

# %%
df.rename(columns={
     'Cadidate':'Winning Candidate', 
     'Party':'Winning Party',
       'Votes (Vote%)':'Winner\'s Votes', 
       'Candidate.1':'Runner Up Candidate',
       'Party.1' : 'Runner Up Party', 
       'Votes (Vote%)': 'Runner Up Votes',
}, inplace=True)

# %%
df.head(5)
# Out:
#    No.                         Name  Type                  Candidate  \
# 0    1  Andaman and Nicobar Islands   GEN         Kuldeep Rai Sharma
# 1    1                        Araku  (ST)            Goddeti Madhavi
# 2    2                   Srikakulam   GEN  Ram Mohan Naidu Kinjarapu
# 3    3                 Vizianagaram   GEN     Bellana Chandra Sekhar
# 4    4                Visakhapatnam   GEN     M. V. V. Satyanarayana
#
#   Winning Party    Runner Up Votes   Runner Up Candidate  \
# 0           INC    95,308 (45.95%)          Vishal Jolly
# 1         YSRCP  5,62,190 (52.14%)   Kishore Chandra Deo
# 2           TDP  5,34,544 (45.91%)      Duvvada Srinivas
# 3         YSRCP  5,78,418 (47.32%)  Ashok Gajapathi Raju
# 4         YSRCP  4,36,906 (35.24%)   Bharat Mathukumilli
#
#           Runner Up Party    Votes (Vote%).1    Margin Margin %  \
# 0  Bharatiya Janata Party    93,901 (45.28%)     1,407    0.67%
# 1                     TDP  3,38,101 (31.36%)  2,24,089   20.78%
# ...

# %%
df.isna().sum()
# Out:
# No.                      0
# Name                     0
# Type                     0
# Candidate                0
# Winning Party            0
# Runner Up Votes          0
# Runner Up Candidate      0
# Runner Up Party          0
# Votes (Vote%).1          0
# Margin                   0
# Margin %               486
# State                   45
# dtype: int64

# %%
df[['State', 'Name']][df['State'].isna()]
# Out:
#     State                    Name
# 30    NaN     Autonomous District
# 34    NaN                 Gauhati
# 35    NaN               Mangaldoi
# 36    NaN                  Tezpur
# 37    NaN                 Nowgong
# 38    NaN                Kaliabor
# 85    NaN          Janjgir-Champa
# 94    NaN  Dadra And Nagar Haveli
# 95    NaN           Daman And Diu
# 138   NaN    Bhiwani–Mahendragarh
# 147   NaN                Anantnag
# 155   NaN                 Kodarma
# 162   NaN               Lohardaga
# 163   NaN                 Palamau
# 208   NaN             Mavelikkara
# 215   NaN                   Bhind
# 219   NaN               Tikamgarh
# 221   NaN               Khajuraho
# 224   NaN                   Sidhi
# 225   NaN                 Shahdol
# 232   NaN                  Bhopal
# 233   NaN                 Rajgarh
# 253   NaN        Bhandara-Gondiya
# 254   NaN       Gadchiroli-Chimur
# 256   NaN         Yavatmal-Washim
# 288   NaN    Ratnagiri-Sindhudurg
# ...

# %%
missing_constituency_to_state = {
    'Janjgir-Champa': 'Chhattisgarh',
    'Dadra And Nagar Haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'Bhiwani–Mahendragarh': 'Haryana',
    'Anantnag-Rajouri': 'Jammu and Kashmir',
    'Kodarma': 'Jharkhand',
    'Lohardaga': 'Jharkhand',
    'Palamau': 'Jharkhand',
    'Mavelikkara': 'Kerala',
    'Bhind': 'Madhya Pradesh',
    'Tikamgarh': 'Madhya Pradesh',
    'Khajuraho': 'Madhya Pradesh',
    'Sidhi': 'Madhya Pradesh',
    'Shahdol': 'Madhya Pradesh',
    'Bhopal': 'Madhya Pradesh',
    'Rajgarh': 'Madhya Pradesh',
    'Bhandara-Gondiya': 'Maharashtra',
    'Gadchiroli-Chimur': 'Maharashtra',
    'Yavatmal-Washim': 'Maharashtra',
    'Ratnagiri-Sindhudurg': 'Maharashtra',
    'Ferozpur': 'Punjab',
    'Mayiladuthurai': 'Tamil Nadu',
    'Thoothukudi': 'Tamil Nadu',
    'Peddapalli': 'Telangana',
    'Gautam Buddh Nagar': 'Uttar Pradesh',
    'Kanpur Urban': 'Uttar Pradesh',
    'Nainital-Udhamsingh Nagar': 'Uttarakhand',
    'Maldaha Uttar': 'West Bengal',
    'Maldaha Dakshin': 'West Bengal',
    'Bangaon': 'West Bengal',
    'Barrackpur': 'West Bengal',
    'Dum Dum': 'West Bengal',
    'Barasat': 'West Bengal',
    'Basirhat': 'West Bengal',
    'Joynagar': 'West Bengal',
    'Mathurapur': 'West Bengal',
    'Diamond Harbour': 'West Bengal',
    'Bardhaman-Durgapur': 'West Bengal',
    'Bolpur': 'West Bengal'
}
df['State'] = df['State'].fillna(df['Name'].map(missing_constituency_to_state))

# %%
df.isna().sum()
# Out:
# No.                      0
# Name                     0
# Type                     0
# Candidate                0
# Winning Party            0
# Runner Up Votes          0
# Runner Up Candidate      0
# Runner Up Party          0
# Votes (Vote%).1          0
# Margin                   0
# Margin %               486
# State                   12
# dtype: int64

# %%
df[['State', 'Name']][df['State'].isna()]
# Out:
#     State                 Name
# 30    NaN  Autonomous District
# 34    NaN              Gauhati
# 35    NaN            Mangaldoi
# 36    NaN               Tezpur
# 37    NaN              Nowgong
# 38    NaN             Kaliabor
# 95    NaN        Daman And Diu
# 147   NaN             Anantnag
# 370   NaN           Viluppuram
# 396   NaN          Kanyakumari
# 515   NaN          Barrackpore
# 519   NaN             Jaynagar

# %%
df['State'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', nan, 'Bihar', 'Uttar Pradesh',
#        'Maharashtra', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Ladakh', 'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep',
#        'Madhya Pradesh', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
missing_constituency_to_state2 = {
    'Autonomous District': 'Assam',
    'Gauhati': 'Assam',
    'Mangaldoi': 'Assam',
    'Tezpur': 'Assam',
    'Nowgong': 'Assam',
    'Kaliabor': 'Assam',
    'Daman And Diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'Anantnag': 'Jammu and Kashmir',
    'Viluppuram': 'Tamil Nadu',
    'Kanyakumari': 'Tamil Nadu',
    'Barrackpore': 'West Bengal',
    'Jaynagar': 'West Bengal'
}
df['State'] = df['State'].fillna(df['Name'].map(missing_constituency_to_state2))

# %%
df.isna().sum()
# Out:
# No.                      0
# Name                     0
# Type                     0
# Candidate                0
# Winning Party            0
# Runner Up Votes          0
# Runner Up Candidate      0
# Runner Up Party          0
# Votes (Vote%).1          0
# Margin                   0
# Margin %               486
# State                    0
# dtype: int64

# %%
df.head(5)
# Out:
#    No.                         Name  Type                  Candidate  \
# 0    1  Andaman and Nicobar Islands   GEN         Kuldeep Rai Sharma
# 1    1                        Araku  (ST)            Goddeti Madhavi
# 2    2                   Srikakulam   GEN  Ram Mohan Naidu Kinjarapu
# 3    3                 Vizianagaram   GEN     Bellana Chandra Sekhar
# 4    4                Visakhapatnam   GEN     M. V. V. Satyanarayana
#
#   Winning Party    Runner Up Votes   Runner Up Candidate  \
# 0           INC    95,308 (45.95%)          Vishal Jolly
# 1         YSRCP  5,62,190 (52.14%)   Kishore Chandra Deo
# 2           TDP  5,34,544 (45.91%)      Duvvada Srinivas
# 3         YSRCP  5,78,418 (47.32%)  Ashok Gajapathi Raju
# 4         YSRCP  4,36,906 (35.24%)   Bharat Mathukumilli
#
#           Runner Up Party    Votes (Vote%).1    Margin Margin %  \
# 0  Bharatiya Janata Party    93,901 (45.28%)     1,407    0.67%
# 1                     TDP  3,38,101 (31.36%)  2,24,089   20.78%
# ...

# %%
df.rename(columns={
       'Runner Up Votes':'Winner\'s Votes', 
       'Votes (Vote%).1': 'Runner Up Votes',
}, inplace=True)
df.head(5)
# Out:
#    No.                         Name  Type                  Candidate  \
# 0    1  Andaman and Nicobar Islands   GEN         Kuldeep Rai Sharma
# 1    1                        Araku  (ST)            Goddeti Madhavi
# 2    2                   Srikakulam   GEN  Ram Mohan Naidu Kinjarapu
# 3    3                 Vizianagaram   GEN     Bellana Chandra Sekhar
# 4    4                Visakhapatnam   GEN     M. V. V. Satyanarayana
#
#   Winning Party     Winner's Votes   Runner Up Candidate  \
# 0           INC    95,308 (45.95%)          Vishal Jolly
# 1         YSRCP  5,62,190 (52.14%)   Kishore Chandra Deo
# 2           TDP  5,34,544 (45.91%)      Duvvada Srinivas
# 3         YSRCP  5,78,418 (47.32%)  Ashok Gajapathi Raju
# 4         YSRCP  4,36,906 (35.24%)   Bharat Mathukumilli
#
#           Runner Up Party    Runner Up Votes    Margin Margin %  \
# 0  Bharatiya Janata Party    93,901 (45.28%)     1,407    0.67%
# 1                     TDP  3,38,101 (31.36%)  2,24,089   20.78%
# ...

# %%
df['Type'].replace({
    '(ST)' : 'ST',
    '(SC)':'SC'
},inplace=True)

# %%
df['Type'].unique()
# Out:
# array(['GEN', 'ST', 'SC', '(GEN)'], dtype=object)

# %%
df['Type'].replace({
    '(GEN)' : 'GEN'
},inplace=True)

# %%
df['Type'].unique()
# Out:
# array(['GEN', 'ST', 'SC'], dtype=object)

# %%
df.dtypes
df['Winner\'s Votes'] = df['Winner\'s Votes'].astype(str)

# %%
df[['Winner_Votes_Clean', 'Winning_Percentage']]=df['Winner\'s Votes'].str.split(' ', expand = True)

# %%
print(df.columns[df.columns.duplicated()])
df.columns
# Out:
# Index([], dtype='object')
# Index(['No.', 'Name', 'Type', 'Candidate', 'Winning Party', 'Winner's Votes',
#        'Runner Up Candidate', 'Runner Up Party', 'Runner Up Votes', 'Margin',
#        'Margin %', 'State', 'Winner_Votes_Clean', 'Winning_Percentage'],
#       dtype='object')

# %%
df.head(5)
df.rename({
    'Winner\'s Votes' : 'Winner\'s Votes',
    'Winner\'s Votes' : 'Runner Up Votes'
})
# Out:
#      No.                         Name Type                  Candidate  \
# 0      1  Andaman and Nicobar Islands  GEN         Kuldeep Rai Sharma
# 1      1                        Araku   ST            Goddeti Madhavi
# 2      2                   Srikakulam  GEN  Ram Mohan Naidu Kinjarapu
# 3      3                 Vizianagaram  GEN     Bellana Chandra Sekhar
# 4      4                Visakhapatnam  GEN     M. V. V. Satyanarayana
# ..   ...                          ...  ...                        ...
# 538   38              Bardhaman Purba   SC         Sunil Kumar Mondal
# 539   39           Bardhaman-Durgapur  GEN            S. S. Ahluwalia
# 540   40                      Asansol  GEN              Babul Supriyo
# 541   41                       Bolpur   SC             Asit Kumar Mal
# 542   42                      Birbhum  GEN               Shatabdi Roy
#
#     Winning Party     Winner's Votes   Runner Up Candidate  \
# 0             INC    95,308 (45.95%)          Vishal Jolly
# ...

# %%
df.columns
# Out:
# Index(['No.', 'Name', 'Type', 'Candidate', 'Winning Party', 'Winner's Votes',
#        'Runner Up Candidate', 'Runner Up Party', 'Runner Up Votes', 'Margin',
#        'Margin %', 'State', 'Winner_Votes_Clean', 'Winning_Percentage'],
#       dtype='object')

# %%
# Print columns with positions
for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: No.
# 1: Name
# 2: Type
# 3: Candidate
# 4: Winning Party
# 5: Winner's Votes
# 6: Runner Up Candidate
# 7: Runner Up Party
# 8: Runner Up Votes
# 9: Margin
# 10: Margin %
# 11: State
# 12: Winner_Votes_Clean
# 13: Winning_Percentage

# %%
df.columns.values[4] = "Winner's Votes"         # keep first one
df.columns.values[7] = "Runner Up Votes"        # rename duplicate

# %%
print(df.columns)
# Out:
# Index(['No.', 'Name', 'Type', 'Candidate', 'Winner's Votes', 'Winner's Votes',
#        'Runner Up Candidate', 'Runner Up Votes', 'Runner Up Votes', 'Margin',
#        'Margin %', 'State', 'Winner_Votes_Clean', 'Winning_Percentage'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    No.                         Name Type                  Candidate  \
# 0    1  Andaman and Nicobar Islands  GEN         Kuldeep Rai Sharma
# 1    1                        Araku   ST            Goddeti Madhavi
# 2    2                   Srikakulam  GEN  Ram Mohan Naidu Kinjarapu
# 3    3                 Vizianagaram  GEN     Bellana Chandra Sekhar
# 4    4                Visakhapatnam  GEN     M. V. V. Satyanarayana
#
#   Winner's Votes     Winner's Votes   Runner Up Candidate  \
# 0            INC    95,308 (45.95%)          Vishal Jolly
# 1          YSRCP  5,62,190 (52.14%)   Kishore Chandra Deo
# 2            TDP  5,34,544 (45.91%)      Duvvada Srinivas
# 3          YSRCP  5,78,418 (47.32%)  Ashok Gajapathi Raju
# 4          YSRCP  4,36,906 (35.24%)   Bharat Mathukumilli
#
#           Runner Up Votes    Runner Up Votes    Margin Margin %  \
# 0  Bharatiya Janata Party    93,901 (45.28%)     1,407    0.67%
# 1                     TDP  3,38,101 (31.36%)  2,24,089   20.78%
# ...

# %%
df[['Winner\'s Votes', 'Winning Percentage']] =df["Winner's Votes"].str.split(' ', n=1, expand=True)

# %%
df.head(5)
df.drop(columns=['Winner_Votes_Clean', 'Winning_Percentage'], inplace=True)

# %%
df.head(5)
df['Winning Percentage'] = df['Winning Percentage'].str.strip('()%')

# %%
df.head(10)
# Out:
#    No.                         Name Type                    Candidate  \
# 0    1  Andaman and Nicobar Islands  GEN           Kuldeep Rai Sharma
# 1    1                        Araku   ST              Goddeti Madhavi
# 2    2                   Srikakulam  GEN    Ram Mohan Naidu Kinjarapu
# 3    3                 Vizianagaram  GEN       Bellana Chandra Sekhar
# 4    4                Visakhapatnam  GEN       M. V. V. Satyanarayana
# 5    5                   Anakapalli  GEN  Beesetti Venkata Satyavathi
# 6    6                     Kakinada  GEN                 Vanga Geetha
# 7    7                   Amalapuram   SC              Chinta Anuradha
# 8    8                  Rajahmundry  GEN               Margani Bharat
# 9    9                  Narasapuram  GEN      Raghu Rama Krishna Raju
#
#   Winner's Votes Winner's Votes              Runner Up Candidate  \
# 0            INC         95,308                     Vishal Jolly
# ...

# %%
df['Runner Up Votes'] = df['Runner Up Votes'].astype(str)

# %%
df['Runner Up Votes'].head(5)
# Out:
#           Runner Up Votes    Runner Up Votes
# 0  Bharatiya Janata Party    93,901 (45.28%)
# 1                     TDP  3,38,101 (31.36%)
# 2                   YSRCP  5,27,891 (45.34%)
# 3                     TDP  5,30,382 (43.39%)
# 4                     TDP  4,32,492 (34.88%)

# %%
print(df.columns[df.columns.duplicated()])
# Out:
# Index(['Winner's Votes', 'Runner Up Votes'], dtype='object')

# %%
for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: No.
# 1: Name
# 2: Type
# 3: Candidate
# 4: Winner's Votes
# 5: Winner's Votes
# 6: Runner Up Candidate
# 7: Runner Up Votes
# 8: Runner Up Votes
# 9: Margin
# 10: Margin %
# 11: State
# 12: Winning Percentage

# %%
df.columns.values[4] = 'Winner Party'
df.columns.values[7] = 'Runner Up Party'

# %%
df.head(3)
# Out:
#    No.                         Name Type                  Candidate  \
# 0    1  Andaman and Nicobar Islands  GEN         Kuldeep Rai Sharma
# 1    1                        Araku   ST            Goddeti Madhavi
# 2    2                   Srikakulam  GEN  Ram Mohan Naidu Kinjarapu
#
#   Winner Party Winner's Votes  Runner Up Candidate         Runner Up Party  \
# 0          INC         95,308         Vishal Jolly  Bharatiya Janata Party
# 1        YSRCP       5,62,190  Kishore Chandra Deo                     TDP
# 2          TDP       5,34,544     Duvvada Srinivas                   YSRCP
#
#      Runner Up Votes    Margin Margin %                        State  \
# 0    93,901 (45.28%)     1,407    0.67%  Andaman and Nicobar Islands
# 1  3,38,101 (31.36%)  2,24,089   20.78%               Andhra Pradesh
# 2  5,27,891 (45.34%)     6,653    0.57%               Andhra Pradesh
#
#   Winning Percentage
# 0              45.95
# 1              52.14
# 2              45.91

# %%
df[['Runner Up Votes', 'Runner Up Percentage']] = df['Runner Up Votes'].str.split(' ', n=1, expand=True)

# %%
df['Runner Up Percentage'] = df['Runner Up Percentage'].str.strip('()%')

# %%
df.head(5)
# Out:
#    No.                         Name Type                  Candidate  \
# 0    1  Andaman and Nicobar Islands  GEN         Kuldeep Rai Sharma
# 1    1                        Araku   ST            Goddeti Madhavi
# 2    2                   Srikakulam  GEN  Ram Mohan Naidu Kinjarapu
# 3    3                 Vizianagaram  GEN     Bellana Chandra Sekhar
# 4    4                Visakhapatnam  GEN     M. V. V. Satyanarayana
#
#   Winner Party Winner's Votes   Runner Up Candidate         Runner Up Party  \
# 0          INC         95,308          Vishal Jolly  Bharatiya Janata Party
# 1        YSRCP       5,62,190   Kishore Chandra Deo                     TDP
# 2          TDP       5,34,544      Duvvada Srinivas                   YSRCP
# 3        YSRCP       5,78,418  Ashok Gajapathi Raju                     TDP
# 4        YSRCP       4,36,906   Bharat Mathukumilli                     TDP
#
#   Runner Up Votes    Margin Margin %                        State  \
# ...

# %%
df['Winner\'s Votes'] = df['Winner\'s Votes'].str.replace(',', '')

# %%
df['Runner Up Votes'] = df['Runner Up Votes'].str.replace(',', '')

# %%
df['Margin'] = df['Margin'].str.replace(',', '')
df['Margin %'] = df['Margin %'].str.strip('()%')

# %%
df.head(5)
len(df.columns)
# Out:
# 14

# %%
new_column_order = [
    'No.', 'State','Name', 'Type', 'Candidate','Winner Party', 'Winner\'s Votes','Winning Percentage',
    'Runner Up Candidate', 'Runner Up Party', 'Runner Up Votes', 'Runner Up Percentage', 'Margin',
    'Margin %'
]
len(new_column_order)
# Out:
# 14

# %%
df = df[new_column_order]

# %%
df = df.astype({
    'Winner\'s Votes' : int,
    'Winning Percentage': float,
    'Runner Up Votes': int,
    'Runner Up Percentage' : float,
    'Margin' : int,
    'Margin %': float
})
df.dtypes
# Out:
# No.                       int64
# State                    object
# Name                     object
# Type                     object
# Candidate                object
# Winner Party             object
# Winner's Votes            int64
# Winning Percentage      float64
# Runner Up Candidate      object
# Runner Up Party          object
# Runner Up Votes           int64
# Runner Up Percentage    float64
# Margin                    int64
# Margin %                float64
# dtype: object

# %%
df.head(5)
# Out:
#    No.                        State                         Name Type  \
# 0    1  Andaman and Nicobar Islands  Andaman and Nicobar Islands  GEN
# 1    1               Andhra Pradesh                        Araku   ST
# 2    2               Andhra Pradesh                   Srikakulam  GEN
# 3    3               Andhra Pradesh                 Vizianagaram  GEN
# 4    4               Andhra Pradesh                Visakhapatnam  GEN
#
#                    Candidate Winner Party  Winner's Votes  Winning Percentage  \
# 0         Kuldeep Rai Sharma          INC           95308               45.95
# 1            Goddeti Madhavi        YSRCP          562190               52.14
# 2  Ram Mohan Naidu Kinjarapu          TDP          534544               45.91
# 3     Bellana Chandra Sekhar        YSRCP          578418               47.32
# 4     M. V. V. Satyanarayana        YSRCP          436906               35.24
#
#     Runner Up Candidate         Runner Up Party  Runner Up Votes  \
# ...

# %%
df['Margin %'] = df['Winning Percentage'] - df['Runner Up Percentage']

# %%
df.head(10)
# Out:
#    No.                        State                         Name Type  \
# 0    1  Andaman and Nicobar Islands  Andaman and Nicobar Islands  GEN
# 1    1               Andhra Pradesh                        Araku   ST
# 2    2               Andhra Pradesh                   Srikakulam  GEN
# 3    3               Andhra Pradesh                 Vizianagaram  GEN
# 4    4               Andhra Pradesh                Visakhapatnam  GEN
# 5    5               Andhra Pradesh                   Anakapalli  GEN
# 6    6               Andhra Pradesh                     Kakinada  GEN
# 7    7               Andhra Pradesh                   Amalapuram   SC
# 8    8               Andhra Pradesh                  Rajahmundry  GEN
# 9    9               Andhra Pradesh                  Narasapuram  GEN
#
#                      Candidate Winner Party  Winner's Votes  \
# 0           Kuldeep Rai Sharma          INC           95308
# 1              Goddeti Madhavi        YSRCP          562190
# ...

# %%
filt = (df['Name'] == 'Autonomous District')
df.loc[filt]
# Out:
#     No.  State                 Name Type       Candidate  \
# 30    3  Assam  Autonomous District   ST  Horen Sing Bey
#
#               Winner Party  Winner's Votes  Winning Percentage  \
# 30  Bharatiya Janata Party          381316                 NaN
#
#    Runner Up Candidate Runner Up Party  Runner Up Votes  Runner Up Percentage  \
# 30   Biren Singh Engti             INC           141690                   NaN
#
#     Margin  Margin %
# 30  239626       NaN

# %%
df['Name'].replace({
    	"Autonomous District" : "Diphu"
}, inplace=True)

# %%
filt = (df['Name'] == 'Autonomous District')
df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [No., State, Name, Type, Candidate, Winner Party, Winner's Votes, Winning Percentage, Runner Up Candidate, Runner Up Party, Runner Up Votes, Runner Up Percentage, Margin, Margin %]
# Index: []

# %%
df.isna().sum()
# Out:
# No.                       0
# State                     0
# Name                      0
# Type                      0
# Candidate                 0
# Winner Party              0
# Winner's Votes            0
# Winning Percentage      515
# Runner Up Candidate       0
# Runner Up Party           0
# Runner Up Votes           0
# Runner Up Percentage    515
# Margin                    0
# Margin %                515
# dtype: int64

# %%
df.to_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/transformed-data/2019-transformed-data.csv')

# %%
df = pd.read_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/transformed-data/2019-transformed-data.csv')
df.head(5)
# Out:
#    Unnamed: 0  No.                        State                         Name  \
# 0           0    1  Andaman and Nicobar Islands  Andaman and Nicobar Islands
# 1           1    1               Andhra Pradesh                        Araku
# 2           2    2               Andhra Pradesh                   Srikakulam
# 3           3    3               Andhra Pradesh                 Vizianagaram
# 4           4    4               Andhra Pradesh                Visakhapatnam
#
#   Type                  Candidate Winner Party  Winner's Votes  \
# 0  GEN         Kuldeep Rai Sharma          INC           95308
# 1   ST            Goddeti Madhavi        YSRCP          562190
# 2  GEN  Ram Mohan Naidu Kinjarapu          TDP          534544
# 3  GEN     Bellana Chandra Sekhar        YSRCP          578418
# 4  GEN     M. V. V. Satyanarayana        YSRCP          436906
#
#    Winning Percentage   Runner Up Candidate         Runner Up Party  \
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df['State']=df['State'].replace({
        'Andaman & Nicobar' : 'Andaman and Nicobar Islands',
        'Andaman And Nicobar Islands' : 'Andaman and Nicobar Islands',
        'Dadar & Nagar Haveli' : 'Dadra And Nagar Haveli',
        'Daman & diu' : 'Daman And Diu',
        'Jammu & Kashmir' : 'Jammu And Kashmir',
        'Jammu and Kashmir' : 'Jammu And Kashmir',
        'Orissa' : 'Odisha',
        'Pondicherry' : 'Puducherry'
    })

# %%
const_rename_map = {
        "Cuddapah": "Kadapa",
        "Autonomous District": "Diphu",
        "Mangaldoi": "Darrang–Udalguri",
        "Tezpur": "Sonitpur",
        "Chapra": "Saran",
        "Mormugao": "South Goa",
        "Baroda":  "Vadodara",
        "Broach":  "Bharuch",
        "Bulsar":  "Valsad",
        "Anantnag": "Anantnag–Rajouri",
        "Canara":    "Uttara Kannada",
        "Mangalore": "Dakshina Kannada",
        "Cannanore":  "Kannur",
        "Calicut":    "Kozhikode",
        "Trivandrum": "Thiruvananthapuram",
        "Alleppey":   "Alappuzha",
        "Quilon":     "Kollam",
        "Jhabua": "Ratlam",
        "Bombay South":         "Mumbai South",
        "Bombay South Central": "Mumbai South Central",
        "Bombay North West":    "Mumbai North West",
        "Bombay North East":    "Mumbai North East",
        "Bombay North Central": "Mumbai North Central",
        "Bombay North":         "Mumbai North",
        "Phulbani":  "Kandhamal",
        "Berhampur": "Brahmapur",
        "Ferozepur": "Firozpur",
        "Jullundur": "Jalandhar",
        "Madras South":   "Chennai South",
        "Madras North":   "Chennai North",
        "Madras Central": "Chennai Central",
        "Bara Banki": "Barabanki",
        "Nainital": "Nainital–Udhamsingh Nagar",
        "Calcutta South": "Kolkata Dakshin", 
        "Calcutta North": "Kolkata Uttar",
        "Pondicherry": "Puducherry"
}
df["Name"] = df['Name'].replace(const_rename_map)

# %%
alias_map = {
    # ─────────────────────────  Andhra Pradesh  ──────────────────────
    "Narasapuram":                     "Narsapuram",
    "Narsapuram":                      "Narsapuram",

    # ───────────────────────────────  Assam  ─────────────────────────
    "Gauhati":                         "Guwahati",
    "Guwahati":                        "Guwahati",
    "Nagaon":                          "Nowgong",
    "Nawgong":                         "Nowgong",
    "Nowgong":                         "Nowgong",

    # ─────────────────────────  Chhattisgarh  ────────────────────────
    "Sarguja":                         "Surguja",
    "Surguja":                         "Surguja",
    "Janjgir":                         "Janjgir‑Champa",
    "Janjgir-Champa":                  "Janjgir‑Champa",
    "Janjgir‑Champa":                  "Janjgir‑Champa",   # en‑dash variant

    # ───────────────────────────  Gujarat  ──────────────────────────
    "Kachchh":                         "Kachchh",
    "Kutch":                           "Kachchh",
    "Mahesana":                        "Mahesana",
    "Mehsana":                         "Mahesana",

    # ────────────────────────────  Haryana  ─────────────────────────
    "Bhiwani":                         "Bhiwani‑Mahendragarh",
    "Bhiwani-Mahendragarh":            "Bhiwani‑Mahendragarh",
    "Bhiwani–Mahendragarh":            "Bhiwani‑Mahendragarh",
    "Mahendragarh":                    "Bhiwani‑Mahendragarh",

    # ────────────────  Jammu & Kashmir (Union Territory)  ───────────
    "Anantnag-Rajouri":                "Anantnag‑Rajouri",
    "Anantnag–Rajouri":                "Anantnag‑Rajouri",
    "Anantnag‑Rajouri":                "Anantnag‑Rajouri",

    # ───────────────────────────  Jharkhand  ────────────────────────
    "Palamau":                         "Palamu",
    "Palamu":                          "Palamu",

    # ───────────────────────────  Karnataka  ────────────────────────
    "Dharwad":                         "Dharwad",
    "Haveri":                          "Haveri",

    "Kanara":                          "Uttara Kannada",
    "Uttara Kannada":                  "Uttara Kannada",
    "Udupi Chikmagalur":               "Udupi Chikmagalur",

    # ────────────────────────────  Kerala  ──────────────────────────
    "Palakkad":                        "Palakkad",
    "Palghat":                         "Palakkad",
    "Thrissur":                        "Thrissur",
    "Trichur":                         "Thrissur",

    # ──────────────────────────  Maharashtra  ───────────────────────
    "Bhandara":                        "Bhandara‑Gondiya",
    "Bhandara-Gondiya":                "Bhandara‑Gondiya",
    "Bhandara‑Gondiya":                "Bhandara‑Gondiya",

    "Chimur":                          "Gadchiroli‑Chimur",
    "Gadchiroli-Chimur":               "Gadchiroli‑Chimur",
    "Gadchiroli‑Chimur":               "Gadchiroli‑Chimur",

    "Dahanu":                          "Palghar",
    "Palghar":                         "Palghar",

    "Dhule":                           "Dhule",

    "Kolaba":                          "Raigad",
    "Raigad":                          "Raigad",

    "Malegaon":                        "Malegaon",

    # Mumbai seats – unify hyphen / space variants
    "Mumbai North":                    "Mumbai North",
    "Mumbai-North":                    "Mumbai North",

    "Mumbai North Central":            "Mumbai North Central",
    "Mumbai-North-Central":            "Mumbai North Central",

    "Mumbai North East":               "Mumbai North East",
    "Mumbai-North-East":               "Mumbai North East",

    "Mumbai North West":               "Mumbai North West",
    "Mumbai-North-West":               "Mumbai North West",

    "Mumbai South":                    "Mumbai South",
    "Mumbai-South":                    "Mumbai South",

    "Mumbai South Central":            "Mumbai South Central",
    "Mumbai-South-Central":            "Mumbai South Central",
    "Ratnagiri-Sindhudurg":            "Ratnagiri‑Sindhudurg",
    "Ratnagiri‑Sindhudurg":            "Ratnagiri‑Sindhudurg",

    "Yavatmal":                        "Yavatmal‑Washim",
    "Yavatmal-Washim":                 "Yavatmal‑Washim",
    "Yavatmal‑Washim":                 "Yavatmal‑Washim",

    # ───────────────────────────  Rajasthan  ────────────────────────
    "Jhalawar-Baran":                  "Jhalawar‑Baran",
    "Jhalawar–Baran":                  "Jhalawar‑Baran",
    "Jhalawar‑Baran":                  "Jhalawar‑Baran",

    "Karauli-Dholpur":                 "Karauli‑Dholpur",
    "Karauli–Dholpur":                 "Karauli‑Dholpur",
    "Karauli‑Dholpur":                 "Karauli‑Dholpur",

    "Tonk-Sawai Madhopur":             "Tonk‑Sawai Madhopur",
    "Tonk–Sawai Madhopur":             "Tonk‑Sawai Madhopur",
    "Tonk‑Sawai Madhopur":             "Tonk‑Sawai Madhopur",

    # ──────────────────────────  Tamil Nadu  ────────────────────────
    "Chengalpattu":                    "Kancheepuram",
    "Kancheepuram":                    "Kancheepuram",

    "Gobichettipalayam":               "Tiruppur",
    "Tiruppur":                        "Tiruppur",

    "Kanniyakumari":                   "Kanyakumari",
    "Kanyakumari":                     "Kanyakumari",

    "Thoothukkudi":                    "Thoothukkudi",
    "Thoothukudi":                     "Thoothukkudi",

    "Villupuram":                      "Viluppuram",
    "Viluppuram":                      "Viluppuram",

    # ──────────────────────────  Telangana  ─────────────────────────
    "Chelvella":                       "Chevella",
    "Chevella":                        "Chevella",

    "Mahabubnagar":                    "Mahabubnagar",
    "Mahbubnagar":                     "Mahabubnagar",

    # ────────────────────────  Uttar Pradesh  ───────────────────────
    "Balrampur":                       "Balrampur",

    "Gautam Buddh Nagar":              "Gautam Buddha Nagar",
    "Gautam Buddha Nagar":             "Gautam Buddha Nagar",

    "Shravasti":                       "Shravasti",
    "Shrawasti":                       "Shravasti",

    # ────────────────────────  Uttarakhand  ─────────────────────────
    "Hardwar":                         "Haridwar",
    "Haridwar":                        "Haridwar",

    "Nainital-Udhamsingh Nagar":       "Nainital‑Udhamsingh Nagar",
    "Nainital–Udhamsingh Nagar":       "Nainital‑Udhamsingh Nagar",
    "Nainital‑Udhamsingh Nagar":       "Nainital‑Udhamsingh Nagar",

    # ─────────────────────────  West Bengal  ────────────────────────
    "Barrackpore":                     "Barrackpore",
    "Barrackpur":                      "Barrackpore",

    "Bishnupur":"Bishnupur",
    "Vishnupur":"Bishnupur",

    "Contai":"Kanthi",
    "Kanthi":"Kanthi",

    "Krishnagar":"Krishnanagar",
    "Krishnanagar":"Krishnanagar",

    "Medinipur":"Medinipur",
    "Midnapore":"Medinipur",
}

df['Name'] = df['Name'].replace(alias_map)
df['Name'] = df['Name'].str.strip()

# %%
df['Name'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Araku', 'Srikakulam',
#        'Vizianagaram', 'Visakhapatnam', 'Anakapalli', 'Kakinada',
#        'Amalapuram', 'Rajahmundry', 'Narsapuram', 'Eluru',
#        'Machilipatnam', 'Vijayawada', 'Guntur', 'Narasaraopet', 'Bapatla',
#        'Ongole', 'Nandyal', 'Kurnool', 'Anantapur', 'Hindupur', 'Kadapa',
#        'Nellore', 'Tirupati', 'Rajampet', 'Chittoor', 'Arunachal West',
#        'Arunachal East', 'Karimganj', 'Silchar', 'Diphu', 'Dhubri',
#        'Kokrajhar', 'Barpeta', 'Guwahati', 'Darrang–Udalguri', 'Sonitpur',
#        'Nowgong', 'Kaliabor', 'Jorhat', 'Dibrugarh', 'Lakhimpur',
#        'Valmiki Nagar', 'Paschim Champaran', 'Purvi Champaran', 'Sheohar',
#        'Sitamarhi', 'Madhubani', 'Jhanjharpur', 'Supaul', 'Araria',
#        'Kishanganj', 'Katihar', 'Purnia', 'Madhepura', 'Darbhanga',
#        'Muzaffarpur', 'Vaishali', 'Gopalganj', 'Siwan', 'Maharajganj',
#        'Saran', 'Hajipur', 'Ujiarpur', 'Samastipur', 'Begusarai',
# ...

# %%
df['Name']=df['Name'].str.replace('&', 'and', regex = False) \
                                       .str.replace(r"\s+\(SC\)|\s+\(ST\)", "", regex=False) \
                                       .str.replace('-|-','',regex=False) \
                                       .str.title()

# %%
df.to_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/transformed-data/2019-transformed-data.csv')
df.head(5)
# Out:
#    No.                        State                         Name Type  \
# 0    1  Andaman and Nicobar Islands  Andaman And Nicobar Islands  GEN
# 1    1               Andhra Pradesh                        Araku   ST
# 2    2               Andhra Pradesh                   Srikakulam  GEN
# 3    3               Andhra Pradesh                 Vizianagaram  GEN
# 4    4               Andhra Pradesh                Visakhapatnam  GEN
#
#                    Candidate Winner Party  Winner's Votes  Winning Percentage  \
# 0         Kuldeep Rai Sharma          INC           95308               45.95
# 1            Goddeti Madhavi        YSRCP          562190               52.14
# 2  Ram Mohan Naidu Kinjarapu          TDP          534544               45.91
# 3     Bellana Chandra Sekhar        YSRCP          578418               47.32
# 4     M. V. V. Satyanarayana        YSRCP          436906               35.24
#
#     Runner Up Candidate         Runner Up Party  Runner Up Votes  \
# ...

# %%
df['State']
# Out:
# 0      Andaman and Nicobar Islands
# 1                   Andhra Pradesh
# 2                   Andhra Pradesh
# 3                   Andhra Pradesh
# 4                   Andhra Pradesh
#                   ...
# 538                    West Bengal
# 539                    West Bengal
# 540                    West Bengal
# 541                    West Bengal
# 542                    West Bengal
# Name: State, Length: 543, dtype: object

# %%
for i in year:
    filt = dfs[i]['Name'] == 'Nan'
    print(i, ':' ,dfs[i]['Name'].loc[filt])
# Out:
# 1980 : Series([], Name: Name, dtype: object)
# 1984 : Series([], Name: Name, dtype: object)
# 1989 : Series([], Name: Name, dtype: object)
# 1991 : Series([], Name: Name, dtype: object)
# 1996 : Series([], Name: Name, dtype: object)
# 1998 : Series([], Name: Name, dtype: object)
# 1999 : Series([], Name: Name, dtype: object)
# 2004 : Series([], Name: Name, dtype: object)
# 2009 : Series([], Name: Name, dtype: object)
# 2014 : Series([], Name: Name, dtype: object)
# 2019 : Series([], Name: Name, dtype: object)
# 2024 : Series([], Name: Name, dtype: object)

# %%
df.to_csv('/Users/badrinathsanagavaram/Desktop/Election Data Analysis/Data/transformed-data/2019-transformed-data.csv')

# %%
dfs[2024]
# Out:
#    Unnamed: 0           Name Type          Winning Candidate Winning Party  \
# 0           0     Srikakulam  GEN  Kinjarapu Ram Mohan Naidu           TDP
# 1           1   Vizianagaram  GEN      Appalanaidu Kalisetti           TDP
# 2           2  Visakhapatnam  GEN        Mathukumilli Bharat           TDP
# 3           3     Anakapalli  GEN               C. M. Ramesh           BJP
# 4           4       Kakinada  GEN     Tangella Uday Srinivas           JSP
#
#    Winning Percentage  Winner's Votes     Runner Up Candidate Runner Up Party  \
# 0                  61          754328            Perada Tilak           YSRCP
# 1                  57          743113  Bellana Chandra Sekhar           YSRCP
# 2                  65          907467    Botsa Jhansi Lakshmi           YSRCP
# 3                  57          762069      Budi Mutyala Naidu           YSRCP
# 4                  54          729699    Chalamalasetti Sunil           YSRCP
#
# ...
